# %%
import pandas as pd

# %%
data_train = pd.read_csv('Train_Acitivity_Tracker_Labeled.csv')
data_train
# Out:
#         Unnamed: 0         0         1         2  user  experiment  index  \
# 0                0  1.020833 -0.125000  0.105556     1           1    250
# 1                1  1.025000 -0.125000  0.101389     1           1    251
# 2                2  1.020833 -0.125000  0.104167     1           1    252
# 3                3  1.016667 -0.125000  0.108333     1           1    253
# 4                4  1.018056 -0.127778  0.108333     1           1    254
# ...            ...       ...       ...       ...   ...         ...    ...
# 745211      745211  0.636111 -0.433333 -0.065278    56          28  19639
# 745212      745212  0.690278 -0.431944 -0.108333    56          28  19640
# 745213      745213  0.829167 -0.370833 -0.223611    56          28  19641
# 745214      745214  0.915278 -0.275000 -0.354167    56          28  19642
# 745215      745215  0.968056 -0.258333 -0.420833    56          28  19643
#
#         labels
# 0            5
# 1            5
# 2            5
# ...

# %%
data_train=data_train.drop('Unnamed: 0', axis=1)

# %%
data_train = data_train.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 data_train = data_train.set_index('index')
#       2 data_train
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\frame.py:5488, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5485                 missing.append(col)
#    5487 if missing:
# -> 5488     raise KeyError(f"None of {missing} are in the columns")
# ...

# %%
data_train.head(60)
# Out:
#               0         1         2  user  experiment  labels
# index
# 250    1.020833 -0.125000  0.105556     1           1       5
# 251    1.025000 -0.125000  0.101389     1           1       5
# 252    1.020833 -0.125000  0.104167     1           1       5
# 253    1.016667 -0.125000  0.108333     1           1       5
# 254    1.018056 -0.127778  0.108333     1           1       5
# 255    1.018056 -0.129167  0.104167     1           1       5
# 256    1.019445 -0.125000  0.101389     1           1       5
# 257    1.016667 -0.123611  0.097222     1           1       5
# 258    1.020833 -0.127778  0.098611     1           1       5
# 259    1.019445 -0.115278  0.094444     1           1       5
# 260    1.019445 -0.119444  0.094444     1           1       5
# 261    1.022222 -0.120833  0.100000     1           1       5
# 262    1.019445 -0.120833  0.100000     1           1       5
# 263    1.016667 -0.120833  0.095833     1           1       5
# ...
